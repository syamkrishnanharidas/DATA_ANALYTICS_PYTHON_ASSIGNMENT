# %% [markdown]
# <a href="https://colab.research.google.com/github/syamkrishnanharidas/DATA_ANALYTICS_PYTHON_ASSIGNMENT/blob/main/IRIS_ASSIGNMENT_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing NumPy and PANDAS
import numpy as np
import pandas as pd

# %%
# 1. Read the dataset to the python environment.
iris_data = pd.read_excel('/content/iris.xls')
# 2. Display the columns in the dataset.
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 3. Calculate the mean of each column of the dataset.
iris_data['SL'].mean()
# Out:
# 5.843333333333334

# %%
# 3. Calculate the mean of each column of the dataset.
iris_data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
# 3. Calculate the mean of each column of the dataset.
iris_data['PL'].mean()
# Out:
# 3.758666666666666

# %%
# 3. Calculate the mean of each column of the dataset.
iris_data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
# 4. Check for the null values present in the dataset.
iris_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
# 5.Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations
# A.Details of Iris-setosa
iris_data.loc[iris_data['Classification'] == 'Iris-setosa', ]
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa
# 11  4.8  3.4  1.6  0.2    Iris-setosa
# 12  4.8  3.0  1.4  0.1    Iris-setosa
# 13  4.3  3.0  1.1  0.1    Iris-setosa
# 14  5.8  4.0  1.2  0.2    Iris-setosa
# 15  5.7  4.4  1.5  0.4    Iris-setosa
# 16  5.4  3.9  1.3  0.4    Iris-setosa
# 17  5.1  3.5  1.4  0.3    Iris-setosa
# 18  5.7  3.8  1.7  0.3    Iris-setosa
# 19  5.1  3.8  1.5  0.3    Iris-setosa
# 20  5.4  3.4  1.7  0.2    Iris-setosa
# 21  5.1  3.7  1.5  0.4    Iris-setosa
# 22  4.6  3.6  1.0  0.2    Iris-setosa
# 23  5.1  3.3  1.7  0.5    Iris-setosa
# ...

# %%
# 5.Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations
# B.Details of Iris-versicolor
iris_data.loc[iris_data['Classification'] == 'Iris-versicolor', ]
# Out:
#      SL   SW   PL   PW   Classification
# 50  7.0  3.2  4.7  1.4  Iris-versicolor
# 51  6.4  3.2  4.5  1.5  Iris-versicolor
# 52  6.9  3.1  4.9  1.5  Iris-versicolor
# 53  5.5  2.3  4.0  1.3  Iris-versicolor
# 54  6.5  2.8  4.6  1.5  Iris-versicolor
# 55  5.7  2.8  4.5  1.3  Iris-versicolor
# 56  6.3  3.3  4.7  1.6  Iris-versicolor
# 57  4.9  2.4  3.3  1.0  Iris-versicolor
# 58  6.6  2.9  4.6  1.3  Iris-versicolor
# 59  5.2  2.7  3.9  1.4  Iris-versicolor
# 60  5.0  2.0  3.5  1.0  Iris-versicolor
# 61  5.9  3.0  4.2  1.5  Iris-versicolor
# 62  6.0  2.2  4.0  1.0  Iris-versicolor
# 63  6.1  2.9  4.7  1.4  Iris-versicolor
# 64  5.6  2.9  3.6  1.3  Iris-versicolor
# 65  6.7  3.1  4.4  1.4  Iris-versicolor
# 66  5.6  3.0  4.5  1.5  Iris-versicolor
# 67  5.8  2.7  4.1  1.0  Iris-versicolor
# 68  6.2  2.2  4.5  1.5  Iris-versicolor
# 69  5.6  2.5  3.9  1.1  Iris-versicolor
# 70  5.9  3.2  4.8  1.8  Iris-versicolor
# 71  6.1  2.8  4.0  1.3  Iris-versicolor
# ...

# %%
# 5.Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations
# C.Iris-virginica
iris_data.loc[iris_data['Classification'] == 'Iris-virginica', ]
# Out:
#       SL   SW   PL   PW  Classification
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
# Column Names
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
# Unique values in the column classification
iris_data['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_data['Classification'].value_counts()
# Out:
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# A.Details of Iris-setosa
iris_data.iloc[:49,0:]
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa
# 11  4.8  3.4  1.6  0.2    Iris-setosa
# 12  4.8  3.0  1.4  0.1    Iris-setosa
# 13  4.3  3.0  1.1  0.1    Iris-setosa
# 14  5.8  4.0  1.2  0.2    Iris-setosa
# 15  5.7  4.4  1.5  0.4    Iris-setosa
# 16  5.4  3.9  1.3  0.4    Iris-setosa
# 17  5.1  3.5  1.4  0.3    Iris-setosa
# 18  5.7  3.8  1.7  0.3    Iris-setosa
# 19  5.1  3.8  1.5  0.3    Iris-setosa
# 20  5.4  3.4  1.7  0.2    Iris-setosa
# 21  5.1  3.7  1.5  0.4    Iris-setosa
# 22  4.6  3.6  1.0  0.2    Iris-setosa
# 23  5.1  3.3  1.7  0.5    Iris-setosa
# ...

# %%
# A.Details of Iris-versicolor
iris_data.iloc[50:99,0:]
# Out:
#      SL   SW   PL   PW   Classification
# 50  7.0  3.2  4.7  1.4  Iris-versicolor
# 51  6.4  3.2  4.5  1.5  Iris-versicolor
# 52  6.9  3.1  4.9  1.5  Iris-versicolor
# 53  5.5  2.3  4.0  1.3  Iris-versicolor
# 54  6.5  2.8  4.6  1.5  Iris-versicolor
# 55  5.7  2.8  4.5  1.3  Iris-versicolor
# 56  6.3  3.3  4.7  1.6  Iris-versicolor
# 57  4.9  2.4  3.3  1.0  Iris-versicolor
# 58  6.6  2.9  4.6  1.3  Iris-versicolor
# 59  5.2  2.7  3.9  1.4  Iris-versicolor
# 60  5.0  2.0  3.5  1.0  Iris-versicolor
# 61  5.9  3.0  4.2  1.5  Iris-versicolor
# 62  6.0  2.2  4.0  1.0  Iris-versicolor
# 63  6.1  2.9  4.7  1.4  Iris-versicolor
# 64  5.6  2.9  3.6  1.3  Iris-versicolor
# 65  6.7  3.1  4.4  1.4  Iris-versicolor
# 66  5.6  3.0  4.5  1.5  Iris-versicolor
# 67  5.8  2.7  4.1  1.0  Iris-versicolor
# 68  6.2  2.2  4.5  1.5  Iris-versicolor
# 69  5.6  2.5  3.9  1.1  Iris-versicolor
# 70  5.9  3.2  4.8  1.8  Iris-versicolor
# 71  6.1  2.8  4.0  1.3  Iris-versicolor
# ...

# %%
# A.Details of Iris-virginica
iris_data.iloc[100:149,0:]
# Out:
#       SL   SW   PL   PW  Classification
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
# Information about dataset
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Detailed description of the dataset
iris_data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#sample data taken in random order
iris_data.sample(frac=0.20)
# Out:
#       SL   SW   PL   PW   Classification
# 63   6.1  2.9  4.7  1.4  Iris-versicolor
# 36   5.5  3.5  1.3  0.2      Iris-setosa
# 35   5.0  3.2  1.2  0.2      Iris-setosa
# 3    4.6  3.1  1.5  0.2      Iris-setosa
# 58   6.6  2.9  4.6  1.3  Iris-versicolor
# 41   4.5  2.3  1.3  0.3      Iris-setosa
# 121  5.6  2.8  4.9  2.0   Iris-virginica
# 25   5.0  3.0  1.6  0.2      Iris-setosa
# 142  5.8  2.7  5.1  1.9   Iris-virginica
# 144  6.7  3.3  5.7  2.5   Iris-virginica
# 49   5.0  3.3  1.4  0.2      Iris-setosa
# 22   4.6  3.6  1.0  0.2      Iris-setosa
# 103  6.3  2.9  5.6  1.8   Iris-virginica
# 140  6.7  3.1  5.6  2.4   Iris-virginica
# 119  6.0  2.2  5.0  1.5   Iris-virginica
# 27   5.2  3.5  1.5  0.2      Iris-setosa
# 61   5.9  3.0  4.2  1.5  Iris-versicolor
# 114  5.8  2.8  5.1  2.4   Iris-virginica
# 125  7.2  3.2  6.0  1.8   Iris-virginica
# 100  6.3  3.3  6.0  2.5   Iris-virginica
# 15   5.7  4.4  1.5  0.4      Iris-setosa
# 32   5.2  4.1  1.5  0.1      Iris-setosa
# ...
